# %%
# SymPy reference
from sympy import *
x = symbols('x')
init_printing()
Integral(3*x**2 + 2*x + 1, (x, 0, 2))
# Out:
# 2
# ⌠
# ⎮ ⎛   2          ⎞
# ⎮ ⎝3⋅x  + 2⋅x + 1⎠ dx
# ⌡
# 0

# %%
# Hekatan
import sys
sys.path.insert(0, r"C:\Users\j-b-j\Documents\pyhekatan\src")
from hekatan import *
integral("3*x^2 + 2*x + 1", "x", "0", "2", "I")
# Out:
# <div class="hekatan-doc"><div class="eq"><var>I</var> = <span class="nary-wrap"><span class="nary-sup"><i>2</i></span><span class="nary">&#8747;</span><span class="nary-sub"><i>0</i></span></span><span>(<i>3</i><var>x</var><sup><i>2</i></sup> + <i>2</i><var>x</var> + <i>1</i>) <i>d</i><var>x</var></span></div></div>
