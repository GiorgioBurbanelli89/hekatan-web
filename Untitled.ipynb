# %% [raw]
# from sympy import *
# x = symbols('x')
# integrate(3*x**2 + 2*x + 1, (x, 0, 2))

# %% [raw]
# init_printing()
# Integral(3*x**2 + 2*x + 1, (x, 0, 2))

# %% [raw]
# import sys; sys.path.insert(0, r"C:\Users\j-b-j\Documents\pyhekatan\src")
# from hekatan import *
# integral("3*x^2 + 2*x + 1", "x", "0", "2", "I")
